# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
loaded_array = np.load('../eeg_imgs/568657.npy')

# %%
loaded_array.shape
# Out:
# (1000, 1500, 4)

# %%
plt.imshow(loaded_array)

# %%
fig, axs = plt.subplots(1, figsize=(50, 60))
axs.imshow(loaded_array, cmap='gray') 
axs.axis('off')
plt.show()
